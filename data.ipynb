# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arvanshul/gurgaon-real-estate-99acres-com")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/arvanshul/gurgaon-real-estate-99acres-com?dataset_version_number=2...
# 100%|██████████| 14.1M/14.1M [00:03<00:00, 4.30MB/s]
# Extracting files...
# Path to dataset files: C:\Users\rewav\.cache\kagglehub\datasets\arvanshul\gurgaon-real-estate-99acres-com\versions\2

# %%
import pandas as pd

df = pd.DataFrame()
